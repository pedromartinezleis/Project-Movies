# %%
import requests 
import json
import os
from dotenv import load_dotenv
import pandas as pd
from pandas import json_normalize
import time

# %%
#!pip install imdbpy

# %%
import imdb

# %%
token = "k_uzahin65" #.env por diooooooooos(mensaje de Sonia)

# %%
df = pd.read_csv("IMDb movies.csv",encoding = "ISO-8859-1")
# Out:
# /home/pedro/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### df.head()

# %%
### Intento de Cristopher Nolan####

# %%
url = "https://imdb-api.com/en/API/SearchMovie/k_uzahin65/Interstellar"

# %%
parameters = {"Authorization": f"token {token}"}

# %%
#peli = requests.get(url, params=parameters).json()

# %%
#peli

# %%
#df2 = df[df["title"] == "Interstellar"]

# %%
#df2.columns

# %%
#df2.head()

# %% [markdown]
# ## Filtro mi dataset original

# %%
nolan = df[df["director"] == "Christopher Nolan"]
nolan
# Out:
#       imdb_title_id                             title         original_title  \
# 33306     tt0154506                         Following              Following
# 36475     tt0209144                           Memento                Memento
# 39779     tt0278504                          Insomnia               Insomnia
# 43935     tt0372784                     Batman Begins          Batman Begins
# 48078     tt0468569               Il cavaliere oscuro        The Dark Knight
# 48754     tt0482571                      The Prestige           The Prestige
# 50294     tt0816692                      Interstellar           Interstellar
# 57234     tt1345836  Il cavaliere oscuro - Il ritorno  The Dark Knight Rises
# 57475     tt1375666                         Inception              Inception
# 76459     tt5013056                           Dunkirk                Dunkirk
# 81088     tt6723592                             Tenet                  Tenet
#
# ...

# %%
nolan.to_csv("nolan.csv", index =False)

# %% [markdown]
# #### Parte Vengadores #####

# %%
marvel = df[df["production_company"] == "Marvel Studios"]
marvel
# Out:
#       imdb_title_id                            title  \
# 50773     tt0848228                     The Avengers
# 55465     tt1211837                   Doctor Strange
# 56671     tt1300854                       Iron Man 3
# 62334     tt1825683                    Black Panther
# 63622     tt1981115             Thor: The Dark World
# 63873     tt2015381         Guardiani della Galassia
# 67001     tt2395427          Avengers: Age of Ultron
# 71476     tt3498820       Captain America: Civil War
# 73072     tt3896198  Guardiani della Galassia Vol. 2
# 73864     tt4154756           Avengers: Infinity War
# 73865     tt4154796                Avengers: Endgame
# 76734     tt5095030             Ant-Man and the Wasp
#
#                        original_title  year date_published  \
# 50773                    The Avengers  2012     2012-04-25
# 55465                  Doctor Strange  2016     2016-10-26
# 56671                  Iron Man Three  2013     2013-04-24
# ...

# %%
url_avengers = "https://imdb-api.com/en/API/SearchMovie/k_uzahin65/Avengers"

# %%
avengers = requests.get(url_avengers, params=parameters).json()

# %%
avengers
# Out:
# {'searchType': 'Movie',
#  'expression': 'Avengers',
#  'results': [{'id': 'tt0848228',
#    'resultType': 'Title',
#    'image': 'https://imdb-api.com/images/original/MV5BNDYxNjQyMjAtNTdiOS00NGYwLWFmNTAtNThmYjU5ZGI2YTI1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_Ratio0.7273_AL_.jpg',
#    'title': 'The Avengers',
#    'description': '(2012)'},
#   {'id': 'tt4154796',
#    'resultType': 'Title',
#    'image': 'https://imdb-api.com/images/original/MV5BMTc5MDE2ODcwNV5BMl5BanBnXkFtZTgwMzI2NzQ2NzM@._V1_Ratio0.7273_AL_.jpg',
#    'title': 'Avengers: Endgame',
#    'description': '(2019)'},
#   {'id': 'tt4154756',
#    'resultType': 'Title',
#    'image': 'https://imdb-api.com/images/original/MV5BMjMxNjY2MDU1OV5BMl5BanBnXkFtZTgwNzY1MTUwNTM@._V1_Ratio0.7273_AL_.jpg',
#    'title': 'Avengers: Infinity War',
#    'description': '(2018)'},
#   {'id': 'tt2395427',
#    'resultType': 'Title',
# ...

# %%
avengers["results"]
# Out:
# [{'id': 'tt0848228',
#   'resultType': 'Title',
#   'image': 'https://imdb-api.com/images/original/MV5BNDYxNjQyMjAtNTdiOS00NGYwLWFmNTAtNThmYjU5ZGI2YTI1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_Ratio0.7273_AL_.jpg',
#   'title': 'The Avengers',
#   'description': '(2012)'},
#  {'id': 'tt4154796',
#   'resultType': 'Title',
#   'image': 'https://imdb-api.com/images/original/MV5BMTc5MDE2ODcwNV5BMl5BanBnXkFtZTgwMzI2NzQ2NzM@._V1_Ratio0.7273_AL_.jpg',
#   'title': 'Avengers: Endgame',
#   'description': '(2019)'},
#  {'id': 'tt4154756',
#   'resultType': 'Title',
#   'image': 'https://imdb-api.com/images/original/MV5BMjMxNjY2MDU1OV5BMl5BanBnXkFtZTgwNzY1MTUwNTM@._V1_Ratio0.7273_AL_.jpg',
#   'title': 'Avengers: Infinity War',
#   'description': '(2018)'},
#  {'id': 'tt2395427',
#   'resultType': 'Title',
#   'image': 'https://imdb-api.com/images/original/MV5BMTM4OGJmNWMtOTM4Ni00NTE3LTg3MDItZmQxYjc4N2JhNmUxXkEyXkFqcGdeQXVyNTgzMDMzMTg@._V1_Ratio0.7273_AL_.jpg',
#   'title': 'Avengers: Age of Ultron',
# ...

# %%
datos = pd.DataFrame(avengers["results"])
datos.head()
# Out:
#           id resultType                                              image  \
# 0  tt0848228      Title  https://imdb-api.com/images/original/MV5BNDYxN...
# 1  tt4154796      Title  https://imdb-api.com/images/original/MV5BMTc5M...
# 2  tt4154756      Title  https://imdb-api.com/images/original/MV5BMjMxN...
# 3  tt2395427      Title  https://imdb-api.com/images/original/MV5BMTM4O...
# 4  tt0118661      Title  https://imdb-api.com/images/original/MV5BYWE1N...
#
#                      title description
# 0             The Avengers      (2012)
# 1        Avengers: Endgame      (2019)
# 2   Avengers: Infinity War      (2018)
# 3  Avengers: Age of Ultron      (2015)
# 4             The Avengers      (1998)

# %%
datos_renom = {"id": "imdb_title_id"}

# %%
datos
# Out:
#           id resultType                                              image  \
# 0  tt0848228      Title  https://imdb-api.com/images/original/MV5BNDYxN...
# 1  tt4154796      Title  https://imdb-api.com/images/original/MV5BMTc5M...
# 2  tt4154756      Title  https://imdb-api.com/images/original/MV5BMjMxN...
# 3  tt2395427      Title  https://imdb-api.com/images/original/MV5BMTM4O...
# 4  tt0118661      Title  https://imdb-api.com/images/original/MV5BYWE1N...
#
#                      title description
# 0             The Avengers      (2012)
# 1        Avengers: Endgame      (2019)
# 2   Avengers: Infinity War      (2018)
# 3  Avengers: Age of Ultron      (2015)
# 4             The Avengers      (1998)

# %%
datos.rename(columns=datos_renom, inplace=True)

# %%
datos
# Out:
#   imdb_title_id resultType                                              image  \
# 0     tt0848228      Title  https://imdb-api.com/images/original/MV5BNDYxN...
# 1     tt4154796      Title  https://imdb-api.com/images/original/MV5BMTc5M...
# 2     tt4154756      Title  https://imdb-api.com/images/original/MV5BMjMxN...
# 3     tt2395427      Title  https://imdb-api.com/images/original/MV5BMTM4O...
# 4     tt0118661      Title  https://imdb-api.com/images/original/MV5BYWE1N...
#
#                      title description
# 0             The Avengers      (2012)
# 1        Avengers: Endgame      (2019)
# 2   Avengers: Infinity War      (2018)
# 3  Avengers: Age of Ultron      (2015)
# 4             The Avengers      (1998)

# %%
datos.drop(["resultType", "title", "description"], axis=1, inplace=True)

# %%
datos
# Out:
#   imdb_title_id                                              image
# 0     tt0848228  https://imdb-api.com/images/original/MV5BNDYxN...
# 1     tt4154796  https://imdb-api.com/images/original/MV5BMTc5M...
# 2     tt4154756  https://imdb-api.com/images/original/MV5BMjMxN...
# 3     tt2395427  https://imdb-api.com/images/original/MV5BMTM4O...
# 4     tt0118661  https://imdb-api.com/images/original/MV5BYWE1N...

# %%
json_normalize(avengers["results"])
# Out:
#           id resultType                                              image  \
# 0  tt0848228      Title  https://imdb-api.com/images/original/MV5BNDYxN...
# 1  tt4154796      Title  https://imdb-api.com/images/original/MV5BMTc5M...
# 2  tt4154756      Title  https://imdb-api.com/images/original/MV5BMjMxN...
# 3  tt2395427      Title  https://imdb-api.com/images/original/MV5BMTM4O...
# 4  tt0118661      Title  https://imdb-api.com/images/original/MV5BYWE1N...
#
#                      title description
# 0             The Avengers      (2012)
# 1        Avengers: Endgame      (2019)
# 2   Avengers: Infinity War      (2018)
# 3  Avengers: Age of Ultron      (2015)
# 4             The Avengers      (1998)

# %%
df_avengers = df[df['title'].str.contains("Avengers")]
#df_avengers = df[df["title"] == "The Avengers"]

# %%
df_avengers
# Out:
#       imdb_title_id                            title  \
# 30382     tt0118661   The Avengers - Agenti speciali
# 50773     tt0848228                     The Avengers
# 67001     tt2395427          Avengers: Age of Ultron
# 73864     tt4154756           Avengers: Infinity War
# 73865     tt4154796                Avengers: Endgame
# 79848     tt6172666  Avengers of Justice: Farce Wars
#
#                         original_title  year date_published  \
# 30382                     The Avengers  1998     1998-10-30
# 50773                     The Avengers  2012     2012-04-25
# 67001          Avengers: Age of Ultron  2015     2015-04-22
# 73864           Avengers: Infinity War  2018     2018-04-25
# 73865                Avengers: Endgame  2019     2019-04-24
# 79848  Avengers of Justice: Farce Wars  2018           2018
#
#                            genre  duration country  \
# 30382  Action, Adventure, Sci-Fi        89     USA
# 50773  Action, Adventure, Sci-Fi       143     USA
# ...

# %%
df_avengers.drop([30382,79848], axis=0, inplace=True)
# Out:
# /home/pedro/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_avengers
# Out:
#       imdb_title_id                    title           original_title  year  \
# 50773     tt0848228             The Avengers             The Avengers  2012
# 67001     tt2395427  Avengers: Age of Ultron  Avengers: Age of Ultron  2015
# 73864     tt4154756   Avengers: Infinity War   Avengers: Infinity War  2018
# 73865     tt4154796        Avengers: Endgame        Avengers: Endgame  2019
#
#       date_published                      genre  duration country  \
# 50773     2012-04-25  Action, Adventure, Sci-Fi       143     USA
# 67001     2015-04-22  Action, Adventure, Sci-Fi       141     USA
# 73864     2018-04-25  Action, Adventure, Sci-Fi       149     USA
# 73865     2019-04-24   Action, Adventure, Drama       181     USA
#
#                                language                  director  ...  \
# 50773           English, Russian, Hindi               Joss Whedon  ...
# 67001                   English, Korean               Joss Whedon  ...
# ...

# %%
avengers_df = df_avengers.merge(datos, on='imdb_title_id', how='left')

# %%
avengers_df
# Out:
#   imdb_title_id                    title           original_title  year  \
# 0     tt0848228             The Avengers             The Avengers  2012
# 1     tt2395427  Avengers: Age of Ultron  Avengers: Age of Ultron  2015
# 2     tt4154756   Avengers: Infinity War   Avengers: Infinity War  2018
# 3     tt4154796        Avengers: Endgame        Avengers: Endgame  2019
#
#   date_published                      genre  duration country  \
# 0     2012-04-25  Action, Adventure, Sci-Fi       143     USA
# 1     2015-04-22  Action, Adventure, Sci-Fi       141     USA
# 2     2018-04-25  Action, Adventure, Sci-Fi       149     USA
# 3     2019-04-24   Action, Adventure, Drama       181     USA
#
#                            language                  director  ...  \
# 0           English, Russian, Hindi               Joss Whedon  ...
# 1                   English, Korean               Joss Whedon  ...
# 2                           English  Anthony Russo, Joe Russo  ...
# ...

# %%
avengers_df.to_csv("avengers_df.csv", index = False)
